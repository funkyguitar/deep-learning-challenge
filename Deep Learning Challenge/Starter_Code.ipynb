# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
applicationDropDF = application_df.drop(['EIN', 'NAME'], axis=1)
applicationDropDF
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# 0       Association       1              0                      N      5000
# 1      Co-operative       1         1-9999                      N    108590
# 2       Association       1              0                      N      5000
# 3             Trust       1    10000-24999                      N      6692
# 4             Trust       1  100000-499999                      N    142590
# ...             ...     ...            ...                    ...       ...
# 34294   Association       1              0                      N      5000
# 34295   Association       1              0                      N      5000
# 34296   Association       1              0                      N      5000
# 34297   Association       1              0                      N      5000
# 34298  Co-operative       1          1M-5M                      N  36500179
#
#        IS_SUCCESSFUL
# 0                  1
# 1                  1
# 2                  0
# 3                  1
# 4                  1
# ...              ...
# 34294              0
# 34295              0
# 34296              0
# 34297              1
# 34298              0
#
# [34299 rows x 10 columns]

# %%
# Determine the number of unique values in each column.
n = applicationDropDF.nunique(axis=0)
  
print("No.of.unique values in each column :\n",
      n)
# Out:
# No.of.unique values in each column :
#  APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning

applicationDropDF.APPLICATION_TYPE.value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`

# Replace in dataframe
for app in applicationDropDF:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
applicationDropDF.CLASSIFICATION.value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
applicationDropDF.groupby('CLASSIFICATION').filter(lambda x: len(x) >= 2).CLASSIFICATION.value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1237        9
# C1235        9
# C7210        7
# C4100        6
# C1720        6
# C2400        6
# C1600        5
# C1257        5
# C1260        3
# C2710        3
# C0           3
# C1267        2
# C1256        2
# C1234        2
# C1246        2
# C3200        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`

# Define cutoff value
cutoff = 10

# Create a list of classifications with count less than the cutoff
class_counts = application_df['CLASSIFICATION'].value_counts()
classifications_to_replace = list(class_counts[class_counts < cutoff].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# Other       98
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`

with_dummies_df = pd.get_dummies(applicationDropDF)
with_dummies_df
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_T10  \
# 0           1      5000              1                     1
# 1           1    108590              1                     0
# 2           1      5000              0                     0
# 3           1      6692              1                     0
# 4           1    142590              1                     0
# ...       ...       ...            ...                   ...
# 34294       1      5000              0                     0
# 34295       1      5000              0                     0
# 34296       1      5000              0                     0
# 34297       1      5000              1                     0
# 34298       1  36500179              0                     0
#
#        APPLICATION_TYPE_T12  APPLICATION_TYPE_T13  APPLICATION_TYPE_T14  \
# 0                         0                     0                     0
# 1                         0                     0                     0
# 2                         0                     0                     0
# 3                         0                     0                     0
# 4                         0                     0                     0
# ...                     ...                   ...                   ...
# 34294                     0                     0                     0
# 34295                     0                     0                     0
# 34296                     0                     0                     0
# 34297                     0                     0                     0
# 34298                     0                     0                     0
#
#        APPLICATION_TYPE_T15  APPLICATION_TYPE_T17  APPLICATION_TYPE_T19  ...  \
# 0                         0                     0                     0  ...
# 1                         0                     0                     0  ...
# 2                         0                     0                     0  ...
# 3                         0                     0                     0  ...
# 4                         0                     0                     0  ...
# ...                     ...                   ...                   ...  ...
# 34294                     0                     0                     0  ...
# 34295                     0                     0                     0  ...
# 34296                     0                     0                     0  ...
# 34297                     0                     0                     0  ...
# 34298                     0                     0                     0  ...
#
#        INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0                      0                       0                         0
# 1                      1                       0                         0
# 2                      0                       0                         0
# 3                      0                       1                         0
# 4                      0                       0                         1
# ...                  ...                     ...                       ...
# 34294                  0                       0                         0
# 34295                  0                       0                         0
# 34296                  0                       0                         0
# 34297                  0                       0                         0
# 34298                  0                       0                         0
#
#        INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0                       0                 0                       0
# 1                       0                 0                       0
# 2                       0                 0                       0
# 3                       0                 0                       0
# 4                       0                 0                       0
# ...                   ...               ...                     ...
# 34294                   0                 0                       0
# 34295                   0                 0                       0
# 34296                   0                 0                       0
# 34297                   0                 0                       0
# 34298                   0                 1                       0
#
#        INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0                    0                  0                         1
# 1                    0                  0                         1
# 2                    0                  0                         1
# 3                    0                  0                         1
# 4                    0                  0                         1
# ...                ...                ...                       ...
# 34294                0                  0                         1
# 34295                0                  0                         1
# 34296                0                  0                         1
# 34297                0                  0                         1
# 34298                0                  0                         1
#
#        SPECIAL_CONSIDERATIONS_Y
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
# ...                         ...
# 34294                         0
# 34295                         0
# 34296                         0
# 34297                         0
# 34298                         0
#
# [34299 rows x 117 columns]

# %%
# Split our preprocessed data into our features and target arrays
y = with_dummies_df["IS_SUCCESSFUL"].values
X = with_dummies_df.drop(["IS_SUCCESSFUL"],1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)
# Out:
# <ipython-input-11-f80a2c389a95>:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X = with_dummies_df.drop(["IS_SUCCESSFUL"],1).values

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 =  80
hidden_nodes_layer2 = 30

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                9360
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 11,821
# Trainable params: 11,821
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5759 - accuracy: 0.7238
# Epoch 2/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5554 - accuracy: 0.7299
# Epoch 3/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5512 - accuracy: 0.7328
# Epoch 4/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5481 - accuracy: 0.7345
# Epoch 5/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5469 - accuracy: 0.7330
# Epoch 6/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5451 - accuracy: 0.7336
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5441 - accuracy: 0.7345
# Epoch 8/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5433 - accuracy: 0.7353
# Epoch 9/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5423 - accuracy: 0.7352
# Epoch 10/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5414 - accuracy: 0.7346
# Epoch 11/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5413 - accuracy: 0.7351
# Epoch 12/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5403 - accuracy: 0.7378
# Epoch 13/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5405 - accuracy: 0.7357
# Epoch 14/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5397 - accuracy: 0.7371
# Epoch 15/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5389 - accuracy: 0.7369
# Epoch 16/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5392 - accuracy: 0.7377
# Epoch 17/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5390 - accuracy: 0.7373
# Epoch 18/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5378 - accuracy: 0.7390
# Epoch 19/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5383 - accuracy: 0.7390
# Epoch 20/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5375 - accuracy: 0.7392
# Epoch 21/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5369 - accuracy: 0.7389
# Epoch 22/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5366 - accuracy: 0.7394
# Epoch 23/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5371 - accuracy: 0.7383
# Epoch 24/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5365 - accuracy: 0.7385
# Epoch 25/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5358 - accuracy: 0.7398
# Epoch 26/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5357 - accuracy: 0.7404
# Epoch 27/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5352 - accuracy: 0.7401
# Epoch 28/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5351 - accuracy: 0.7405
# Epoch 29/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5353 - accuracy: 0.7404
# Epoch 30/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5353 - accuracy: 0.7394
# Epoch 31/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5350 - accuracy: 0.7406
# Epoch 32/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5347 - accuracy: 0.7408
# Epoch 33/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5347 - accuracy: 0.7409
# Epoch 34/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5343 - accuracy: 0.7416
# Epoch 35/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5343 - accuracy: 0.7408
# Epoch 36/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5338 - accuracy: 0.7421
# Epoch 37/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5338 - accuracy: 0.7418
# Epoch 38/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5336 - accuracy: 0.7413
# Epoch 39/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5332 - accuracy: 0.7414
# Epoch 40/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5334 - accuracy: 0.7423
# Epoch 41/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5334 - accuracy: 0.7410
# Epoch 42/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5329 - accuracy: 0.7419
# Epoch 43/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5332 - accuracy: 0.7417
# Epoch 44/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5327 - accuracy: 0.7423
# Epoch 45/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5328 - accuracy: 0.7421
# Epoch 46/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5325 - accuracy: 0.7418
# Epoch 47/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5323 - accuracy: 0.7428
# Epoch 48/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5320 - accuracy: 0.7427
# Epoch 49/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5325 - accuracy: 0.7432
# Epoch 50/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5320 - accuracy: 0.7420
# Epoch 51/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5321 - accuracy: 0.7427
# Epoch 52/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5322 - accuracy: 0.7422
# Epoch 53/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5315 - accuracy: 0.7435
# Epoch 54/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5317 - accuracy: 0.7424
# Epoch 55/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5314 - accuracy: 0.7432
# Epoch 56/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5315 - accuracy: 0.7430
# Epoch 57/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5314 - accuracy: 0.7423
# Epoch 58/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5312 - accuracy: 0.7432
# Epoch 59/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5313 - accuracy: 0.7424
# Epoch 60/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5308 - accuracy: 0.7439
# Epoch 61/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5308 - accuracy: 0.7435
# Epoch 62/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5309 - accuracy: 0.7424
# Epoch 63/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5306 - accuracy: 0.7439
# Epoch 64/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5305 - accuracy: 0.7435
# Epoch 65/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5304 - accuracy: 0.7429
# Epoch 66/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5305 - accuracy: 0.7437
# Epoch 67/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5303 - accuracy: 0.7423
# Epoch 68/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5303 - accuracy: 0.7436
# Epoch 69/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5300 - accuracy: 0.7433
# Epoch 70/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5304 - accuracy: 0.7430
# Epoch 71/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5302 - accuracy: 0.7441
# Epoch 72/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5300 - accuracy: 0.7431
# Epoch 73/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5303 - accuracy: 0.7432
# Epoch 74/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5302 - accuracy: 0.7439
# Epoch 75/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5303 - accuracy: 0.7437
# Epoch 76/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5298 - accuracy: 0.7432
# Epoch 77/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5298 - accuracy: 0.7429
# Epoch 78/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5300 - accuracy: 0.7428
# Epoch 79/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5295 - accuracy: 0.7437
# Epoch 80/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5296 - accuracy: 0.7441
# Epoch 81/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5293 - accuracy: 0.7427
# Epoch 82/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5298 - accuracy: 0.7431
# Epoch 83/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5295 - accuracy: 0.7424
# Epoch 84/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5294 - accuracy: 0.7437
# Epoch 85/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5291 - accuracy: 0.7433
# Epoch 86/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5293 - accuracy: 0.7428
# Epoch 87/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5294 - accuracy: 0.7435
# Epoch 88/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5293 - accuracy: 0.7434
# Epoch 89/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5292 - accuracy: 0.7436
# Epoch 90/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5294 - accuracy: 0.7433
# Epoch 91/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5292 - accuracy: 0.7441
# Epoch 92/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5289 - accuracy: 0.7439
# Epoch 93/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5292 - accuracy: 0.7435
# Epoch 94/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5291 - accuracy: 0.7439
# Epoch 95/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5286 - accuracy: 0.7443
# Epoch 96/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5290 - accuracy: 0.7439
# Epoch 97/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5284 - accuracy: 0.7448
# Epoch 98/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5283 - accuracy: 0.7446
# Epoch 99/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5290 - accuracy: 0.7434
# Epoch 100/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5283 - accuracy: 0.7437

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5656 - accuracy: 0.7272 - 429ms/epoch - 2ms/step
# Loss: 0.5655584931373596, Accuracy: 0.7272303104400635

# %%
# Export our model to HDF5 file
nn.save('AlphabetSoupCharity.h5')
